# %%
import pickle
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load LDA Model
with open('../static/model/lda_model.pickle', 'rb') as f:
    lda_model = pickle.load(f)

# Load Dictionary (id2word)
with open('../static/model/id2word.pickle', 'rb') as f:
    id2word = pickle.load(f)

# %%
# Function to predict topic using LDA model
def get_topic(text, lda_model, id2word):
    # Preprocess the input text and convert it to BOW format
    bow_vector = id2word.doc2bow(text.split())
    
    # Get topic probabilities for the input text
    topic_probabilities = lda_model.get_document_topics(bow_vector)
    
    # Select the topic with the highest probability
    topic_id, prob = max(topic_probabilities, key=lambda x: x[1])
    
    # Get topic keywords
    topic_keywords = lda_model.show_topic(topic_id, topn=5)
    return [word for word, prob in topic_keywords]

# %%
# Load GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
# Function to generate a sentence from GPT-2 based on the topic keywords
def generate_topic_sentence(keywords):
    # Convert the list of keywords into a string as a prompt
    prompt = " ".join(keywords)
    
    # Tokenize the prompt for GPT-2
    inputs = tokenizer(prompt, return_tensors="pt")
    
    # Generate text continuation
    outputs = model.generate(inputs["input_ids"], max_length=50, num_return_sequences=1)
    
    # Decode the generated text
    generated_sentence = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_sentence

# %%
# Example usage
text_input = "Food is any substance consumed by an organism for nutritional support. Food is usually of plant, animal."  # Replace with your actual input text
topic_keywords = get_topic(text_input, lda_model, id2word)
generated_sentence = generate_topic_sentence(topic_keywords)

print("Topic Keywords:", topic_keywords)
print("Generated Topic Sentence:", generated_sentence)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Example usage
#       2 text_input = "Food is any substance consumed by an organism for nutritional support. Food is usually of plant, animal."  # Replace with your actual input text
# ----> 3 topic_keywords = get_topic(text_input, lda_model, id2word)
#       4 generated_sentence = generate_topic_sentence(topic_keywords)
#       6 print("Topic Keywords:", topic_keywords)
#
# Cell In[15], line 15, in get_topic(text, lda_model, id2word)
#      12     return []  # Handle case where no valid words are found
#      14 # Get topic probabilities for the input text
# ---> 15 topic_probabilities = lda_model.get_document_topics(bow_vector)
#      17 # Select the topic with the highest probability
#      18 topic_id, prob = max(topic_probabilities, key=lambda x: x[1])
#
# File ~\Desktop\IRWA_project\env\Lib\site-packages\gensim\models\ldamodel.py:1354, in LdaModel.get_document_topics(self, bow, minimum_probability, minimum_phi_value, per_word_topics)
#    1347     kwargs = dict(
#    1348         per_word_topics=per_word_topics,
#    1349         minimum_probability=minimum_probability,
#    1350         minimum_phi_value=minimum_phi_value
#    1351     )
#    1352     return self._apply(corpus, **kwargs)
# -> 1354 gamma, phis = self.inference([bow], collect_sstats=per_word_topics)
#    1355 topic_dist = gamma[0] / sum(gamma[0])  # normalize distribution
#    1357 document_topics = [
#    1358     (topicid, topicvalue) for topicid, topicvalue in enumerate(topic_dist)
#    1359     if topicvalue >= minimum_probability
#    1360 ]
#
# File ~\Desktop\IRWA_project\env\Lib\site-packages\gensim\models\ldamodel.py:706, in LdaModel.inference(self, chunk, collect_sstats)
#     704 Elogthetad = Elogtheta[d, :]
#     705 expElogthetad = expElogtheta[d, :]
# --> 706 expElogbetad = self.expElogbeta[:, ids]
#     708 # The optimal phi_{dwk} is proportional to expElogthetad_k * expElogbetad_kw.
#     709 # phinorm is the normalizer.
#     710 # TODO treat zeros explicitly, instead of adding epsilon?
#     711 phinorm = np.dot(expElogthetad, expElogbetad) + epsilon
#
# IndexError: index 472159 is out of bounds for axis 1 with size 388950

# %%
# Print all vocabulary words with their IDs
for word_id, word in id2word.items():
    print(f"ID: {word_id}, Word: {word}")
# Out:
# ID: 0, Word: access
# ID: 1, Word: accessibility
# ID: 2, Word: across_globe
# ID: 3, Word: amalgamation
# ID: 4, Word: analyse
# ID: 5, Word: analysis
# ID: 6, Word: anywhere
# ID: 7, Word: archaeology
# ID: 8, Word: article
# ID: 9, Word: assist
# ID: 10, Word: beautiful
# ID: 11, Word: become
# ID: 12, Word: capture
# ID: 13, Word: certain
# ID: 14, Word: change
# ID: 15, Word: cloud
# ID: 16, Word: cloud_compute
# ID: 17, Word: combine
# ID: 18, Word: come
# ID: 19, Word: company
# ID: 20, Word: competition
# ID: 21, Word: continuous
# ID: 22, Word: conventional
# ID: 23, Word: create
# ID: 24, Word: creation
# ID: 25, Word: crime
# ID: 26, Word: currently
# ID: 27, Word: data
# ID: 28, Word: database
# ID: 29, Word: datum
# ID: 30, Word: decade
# ID: 31, Word: demand
# ID: 32, Word: development
# ID: 33, Word: disseminate
# ID: 34, Word: domain
# ID: 35, Word: drawback
# ID: 36, Word: dream
# ID: 37, Word: dynamic
# ID: 38, Word: earth
# ID: 39, Word: easier
# ID: 40, Word: easily
# ID: 41, Word: easy
# ID: 42, Word: editing
# ID: 43, Word: efficient
# ID: 44, Word: enable
# ID: 45, Word: environment
# ID: 46, Word: exchange
# ID: 47, Word: facilitation
# ID: 48, Word: far_sighte
# ID: 49, Word: fascinated
# ID: 50, Word: feasibility
# ID: 51, Word: feature
# ID: 52, Word: flexibility
# ID: 53, Word: function
# ID: 54, Word: functionality
# ID: 55, Word: gi
# ID: 56, Word: gis
# ID: 57, Word: grow
# ID: 58, Word: growth
# ID: 59, Word: hardware
# ID: 60, Word: help
# ID: 61, Word: important
# ID: 62, Word: independent
# ID: 63, Word: industry
# ID: 64, Word: information
# ID: 65, Word: infrastructure
# ID: 66, Word: integrate
# ID: 67, Word: integration
# ID: 68, Word: interactive
# ID: 69, Word: know
# ID: 70, Word: lag
# ID: 71, Word: large
# ID: 72, Word: large_volume
# ID: 73, Word: late
# ID: 74, Word: leaps_bound
# ID: 75, Word: location
# ID: 76, Word: long
# ID: 77, Word: loss
# ID: 78, Word: make
# ID: 79, Word: management
# ID: 80, Word: manipulate
# ID: 81, Word: many
# ID: 82, Word: map
# ID: 83, Word: mapping
# ID: 84, Word: move
# ID: 85, Word: movement
# ID: 86, Word: much
# ID: 87, Word: nascent
# ID: 88, Word: need
# ID: 89, Word: observation
# ID: 90, Word: online
# ID: 91, Word: organisation
# ID: 92, Word: other
# ID: 93, Word: otherwise
# ID: 94, Word: pace
# ID: 95, Word: perceive
# ID: 96, Word: pick
# ID: 97, Word: piece
# ID: 75175, Word: venezuela_yeman
# ID: 75176, Word: нan
# ID: 75177, Word: cboe
# ID: 75178, Word: gary_gensler
# ID: 75179, Word: gensler
# ID: 75180, Word: sec_cftc
# ID: 75181, Word: solidx
# ID: 75182, Word: ⅱpolicy
# ID: 75183, Word: bezanis
# ID: 75184, Word: canned_good
# ID: 75185, Word: connolly
# ID: 75186, Word: consignment_store
# ID: 75187, Word: food_pantrie
# ID: 75188, Word: lawnside
# ID: 75189, Word: madelyn
# ID: 75190, Word: managr
# ID: 75191, Word: mears
# ID: 75192, Word: medford
# ID: 75193, Word: mondays_tuesday
# ID: 75194, Word: registered_dietitian
# ID: 75195, Word: shoprite
# ID: 75196, Word: shoprite_medford
# ID: 75197, Word: unsellable
# ID: 75198, Word: zallie
# ID: 75199, Word: flight_ticket
# ID: 75200, Word: gut_wrenching
# ID: 75201, Word: hair_follicle
# ID: 75202, Word: meeclinics
# ID: 75203, Word: meetclinic
# ID: 75204, Word: meetclinicscom
# ID: 75205, Word: passport_visa
# ID: 75206, Word: vascularize
# ID: 75207, Word: btms
# ID: 75208, Word: cryptocoin
# ID: 75209, Word: gobaba
# ID: 75210, Word: adisplay
# ID: 75211, Word: alphabetic
# ID: 75212, Word: artificial_intelligence_devops_ethical
# ID: 75213, Word: catch_exception
# ID: 75214, Word: charat
# ID: 75215, Word: diamondarray
# ID: 75216, Word: hacking_refer_edurekas_official
# ID: 75217, Word: import_javautilscann
# ID: 75218, Word: import_javautilscanner
# ID: 75219, Word: int_rows_systemoutprint
# ID: 75220, Word: int_systemoutprint
# ID: 75221, Word: int_systemoutprint_int_systemoutprint
# ID: 75222, Word: int_systemoutprint_scclose
# ID: 75223, Word: jnum
# ID: 75224, Word: letter_number
# ID: 75225, Word: letterlength
# ID: 75226, Word: new_scanner_systemin
# ID: 75227, Word: num_num_num
# ID: 75228, Word: outer_loop
# ID: 75229, Word: pascals_triangle
# ID: 75230, Word: printnum
# ID: 75231, Word: printstar
# ID: 75232, Word: public_class_edureka
# ID: 75233, Word: pyramidpattern
# ID: 75234, Word: readerclose
# ID: 75235, Word: readernext
# ID: 75236, Word: righttriangle
# ID: 75237, Word: rows_int_systemoutprint
# ID: 75238, Word: rows_scnextint
# ID: 75239, Word: sandglass
# ID: 75240, Word: scanner_sc
# ID: 75241, Word: scclose
# ID: 75242, Word: snextint
# ID: 75243, Word: strings
# ID: 75244, Word: systemoutprint
# ID: 75245, Word: systemoutprint_int
# ID: 75246, Word: systemoutprint_scclose
# ID: 75247, Word: systemoutprintf
# ID: 75248, Word: user_lett
# ID: 75249, Word: user_letter
# ID: 75250, Word: fittest
# ID: 75251, Word: gyeonggi
# ID: 75252, Word: gyoung
# ID: 75253, Word: medibloc
# ID: 75254, Word: mycreditchain
# ID: 75255, Word: overnode
# ID: 75256, Word: pil
# ID: 75257, Word: steemian
# ID: 75258, Word: unnio
# ID: 75259, Word: uunio
# ID: 75260, Word: airline_ticket
# ID: 75261, Word: airlines_flight
# ID: 75262, Word: charging_port
# ID: 75263, Word: check_ins
# ID: 75264, Word: discounts_promotion
# ID: 75265, Word: mileageplus
# ID: 75266, Word: seatback
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pickle
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load LDA model and dictionary
with open('../static/model/lda_model.pickle', 'rb') as f:
    lda_model = pickle.load(f)

with open('../static/model/id2word.pickle', 'rb') as f:
    id2word = pickle.load(f)

# Function to get the most probable topic
def get_most_probable_topic(lda_model, bow):
    topics = lda_model.get_document_topics(bow)
    most_probable_topic = max(topics, key=lambda x: x[1])
    return most_probable_topic[0]

# Example document (Bag of Words format)
example_bow = id2word.doc2bow("Food is any substance consumed by an organism for nutritional support. Food is usually of plant, animal.".split())

# Get the most probable topic for the example document
most_probable_topic_id = get_most_probable_topic(lda_model, example_bow)

# Get the words associated with the most probable topic
topic_words = lda_model.show_topic(most_probable_topic_id, topn=10)
topic_words_str = ' '.join([word for word, prob in topic_words])

# Load GPT-2 model and tokenizer
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Generate a meaningful topic description
input_ids = tokenizer.encode(topic_words_str, return_tensors='pt')
output = model.generate(input_ids, max_length=50, num_return_sequences=1)
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(f"Most Probable Topic ID: {most_probable_topic_id}")
print(f"Topic Words: {topic_words_str}")
print(f"Generated Topic Description: {generated_text}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 22
#      19 example_bow = id2word.doc2bow("Food is any substance consumed by an organism for nutritional support. Food is usually of plant, animal.".split())
#      21 # Get the most probable topic for the example document
# ---> 22 most_probable_topic_id = get_most_probable_topic(lda_model, example_bow)
#      24 # Get the words associated with the most probable topic
#      25 topic_words = lda_model.show_topic(most_probable_topic_id, topn=10)
#
# Cell In[13], line 14, in get_most_probable_topic(lda_model, bow)
#      13 def get_most_probable_topic(lda_model, bow):
# ---> 14     topics = lda_model.get_document_topics(bow)
#      15     most_probable_topic = max(topics, key=lambda x: x[1])
#      16     return most_probable_topic[0]
#
# File ~\Desktop\IRWA_project\env\Lib\site-packages\gensim\models\ldamodel.py:1354, in LdaModel.get_document_topics(self, bow, minimum_probability, minimum_phi_value, per_word_topics)
#    1347     kwargs = dict(
#    1348         per_word_topics=per_word_topics,
#    1349         minimum_probability=minimum_probability,
#    1350         minimum_phi_value=minimum_phi_value
#    1351     )
#    1352     return self._apply(corpus, **kwargs)
# -> 1354 gamma, phis = self.inference([bow], collect_sstats=per_word_topics)
#    1355 topic_dist = gamma[0] / sum(gamma[0])  # normalize distribution
#    1357 document_topics = [
#    1358     (topicid, topicvalue) for topicid, topicvalue in enumerate(topic_dist)
#    1359     if topicvalue >= minimum_probability
#    1360 ]
#
# File ~\Desktop\IRWA_project\env\Lib\site-packages\gensim\models\ldamodel.py:706, in LdaModel.inference(self, chunk, collect_sstats)
#     704 Elogthetad = Elogtheta[d, :]
#     705 expElogthetad = expElogtheta[d, :]
# --> 706 expElogbetad = self.expElogbeta[:, ids]
#     708 # The optimal phi_{dwk} is proportional to expElogthetad_k * expElogbetad_kw.
#     709 # phinorm is the normalizer.
#     710 # TODO treat zeros explicitly, instead of adding epsilon?
#     711 phinorm = np.dot(expElogthetad, expElogbetad) + epsilon
#
# IndexError: index 472159 is out of bounds for axis 1 with size 388950

# %%
import pickle
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load LDA model and dictionary
with open('../static/model/lda_model.pickle', 'rb') as f:
    lda_model = pickle.load(f)

with open('../static/model/id2word.pickle', 'rb') as f:
    id2word = pickle.load(f)

# Function to get the most probable topic
def get_most_probable_topic(lda_model, bow):
    vocab = lda_model.id2word.token2id
    filtered_bow = [(word_id, count) for word_id, count in bow if word_id in vocab]
    
    if not filtered_bow:
        print("No valid words found in the BOW representation.")
        return None  # Return None if no valid words are present
    
    topics = lda_model.get_document_topics(filtered_bow)
    print("Document Topics:", topics)  # Debugging line to see all topic probabilities
    most_probable_topic = max(topics, key=lambda x: x[1])
    return most_probable_topic[0]


# Example document
document = "Climate change is a pressing global issue that affects ecosystems, weather patterns, and human health. Governments and organizations worldwide are implementing policies to reduce carbon emissions and promote renewable energy sources. Public awareness and education on environmental conservation are crucial for fostering sustainable practices. Technological advancements in green energy and waste management are also playing a significant role in mitigating the impacts of climate change."
# Convert document to BoW format, filtering out words not in the dictionary
example_bow = id2word.doc2bow([word for word in document.split() if word in id2word.token2id])

# Get the most probable topic for the example document
most_probable_topic_id = get_most_probable_topic(lda_model, example_bow)

# Get the words associated with the most probable topic
topic_words = lda_model.show_topic(most_probable_topic_id, topn=10)
topic_words_str = ' '.join([word for word, prob in topic_words])

# Load GPT-2 model and tokenizer
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Generate a meaningful topic description
input_ids = tokenizer.encode(topic_words_str, return_tensors='pt')
output = model.generate(input_ids, max_length=50, num_return_sequences=1)
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(f"Most Probable Topic ID: {most_probable_topic_id}")
print(f"Topic Words: {topic_words_str}")
print(f"Generated Topic Description: {generated_text}")
# Out:
# No valid words found in the BOW representation.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[21], line 36
#      33 most_probable_topic_id = get_most_probable_topic(lda_model, example_bow)
#      35 # Get the words associated with the most probable topic
# ---> 36 topic_words = lda_model.show_topic(most_probable_topic_id, topn=10)
#      37 topic_words_str = ' '.join([word for word, prob in topic_words])
#      39 # Load GPT-2 model and tokenizer
#
# File ~\Desktop\IRWA_project\env\Lib\site-packages\gensim\models\ldamodel.py:1218, in LdaModel.show_topic(self, topicid, topn)
#    1201 def show_topic(self, topicid, topn=10):
#    1202     """Get the representation for a single topic. Words here are the actual strings, in constrast to
#    1203     :meth:`~gensim.models.ldamodel.LdaModel.get_topic_terms` that represents words by their vocabulary ID.
#    1204
#    (...)
#    1216
#    1217     """
# -> 1218     return [(self.id2word[id], value) for id, value in self.get_topic_terms(topicid, topn)]
#
# File ~\Desktop\IRWA_project\env\Lib\site-packages\gensim\models\ldamodel.py:1252, in LdaModel.get_topic_terms(self, topicid, topn)
#    1250 topic = topic / topic.sum()  # normalize to probability distribution
#    1251 bestn = matutils.argsort(topic, topn, reverse=True)
# -> 1252 return [(idx, topic[idx]) for idx in bestn]
#
# MemoryError: Unable to allocate 13.8 TiB for an array with shape (5, 388950, 5, 388950) and data type float32
